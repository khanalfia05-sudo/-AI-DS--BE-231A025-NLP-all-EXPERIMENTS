# %% [markdown]
# <a href="https://colab.research.google.com/github/khanalfia05-sudo/-AI-DS--BE-231A025-NLP-all-EXPERIMENTS/blob/main/NLP_EXP_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Name:Khan Alfia Shamusl uin: 231A025
documents = [
    "The sun rises in the east.",
    "I enjoy reading books.",
    "She is learning to play the piano.",
    "We went to the park yesterday.",
    "The children are playing happily."
]

# %%
# Name:Khan Alfia Shamusl uin: 231A025
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %%
documents = [
    "The sun rises in the east.",
    "I enjoy reading books.",
    "She is learning to play the piano.",
    "We went to the park yesterday.",
    "The children are playing happily."
]
for i, document in enumerate(documents):
    print(f"D{i+1}: {document}")
# Out:
# D1: The sun rises in the east.
# D2: I enjoy reading books.
# D3: She is learning to play the piano.
# D4: We went to the park yesterday.
# D5: The children are playing happily.

# %%
# Name:Khan Alfia Shamusl uin: 231A025
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# %%
# Name:Khan Alfia Shamusl uin: 231A025
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
index=['D1', 'D2', 'D3', 'D4', 'D5']
tfidf_df.index = index
tfidf_df
# Out:
#         are    books  children      east    enjoy  happily        in       is  \
# D1  0.00000  0.00000   0.00000  0.435623  0.00000  0.00000  0.435623  0.00000
# D2  0.00000  0.57735   0.00000  0.000000  0.57735  0.00000  0.000000  0.00000
# D3  0.00000  0.00000   0.00000  0.000000  0.00000  0.00000  0.000000  0.40933
# D4  0.00000  0.00000   0.00000  0.000000  0.00000  0.00000  0.000000  0.00000
# D5  0.48127  0.00000   0.48127  0.000000  0.00000  0.48127  0.000000  0.00000
#
#     learning      park  ...  playing  reading     rises      she       sun  \
# D1   0.00000  0.000000  ...  0.00000  0.00000  0.435623  0.00000  0.435623
# D2   0.00000  0.000000  ...  0.00000  0.57735  0.000000  0.00000  0.000000
# D3   0.40933  0.000000  ...  0.00000  0.00000  0.000000  0.40933  0.000000
# D4   0.00000  0.448637  ...  0.00000  0.00000  0.000000  0.00000  0.000000
# D5   0.00000  0.000000  ...  0.48127  0.00000  0.000000  0.00000  0.000000
#
# ...

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Create a DataFrame for better readability
cosine_sim_df = pd.DataFrame(cosine_sim, index=tfidf_df.index, columns=tfidf_df.index)
display(cosine_sim_df)
# Out:
#           D1   D2        D3        D4        D5
# D1  1.000000  0.0  0.113194  0.124063  0.133087
# D2  0.000000  1.0  0.000000  0.000000  0.000000
# D3  0.113194  0.0  1.000000  0.177822  0.062527
# D4  0.124063  0.0  0.177822  1.000000  0.068532
# D5  0.133087  0.0  0.062527  0.068532  1.000000

# %%
print(tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 26 stored elements and shape (5, 22)>
#   Coords	Values
#   (0, 17)	0.4908452385195859
#   (0, 16)	0.43562339004656614
#   (0, 14)	0.43562339004656614
#   (0, 6)	0.43562339004656614
#   (0, 3)	0.43562339004656614
#   (1, 4)	0.5773502691896258
#   (1, 13)	0.5773502691896258
#   (1, 1)	0.5773502691896258
#   (2, 17)	0.23060965827922164
#   (2, 15)	0.40933049048235254
#   (2, 7)	0.40933049048235254
#   (2, 8)	0.40933049048235254
#   (2, 18)	0.3302452623668115
#   (2, 11)	0.40933049048235254
#   (2, 10)	0.40933049048235254
#   (3, 17)	0.2527544390867136
#   (3, 18)	0.36195776305908905
#   (3, 19)	0.44863731768635257
#   (3, 20)	0.44863731768635257
#   (3, 9)	0.44863731768635257
#   (3, 21)	0.44863731768635257
#   (4, 17)	0.27113916705171653
#   (4, 2)	0.481270078046231
#   (4, 0)	0.481270078046231
#   (4, 12)	0.481270078046231
#   (4, 5)	0.481270078046231

# %%
# Name:Khan Alfia Shamusl uin: 231A025
print(tfidf_vectorizer.get_feature_names_out())
# Out:
# ['are' 'books' 'children' 'east' 'enjoy' 'happily' 'in' 'is' 'learning'
#  'park' 'piano' 'play' 'playing' 'reading' 'rises' 'she' 'sun' 'the' 'to'
#  'we' 'went' 'yesterday']

# %%
# Name:Khan Alfia Shamusl uin: 231A025
similarity_matrix = cosine_similarity(tfidf_matrix)
similarity_matrix
# Out:
# array([[1.        , 0.        , 0.11319365, 0.12406331, 0.13308737],
#        [0.        , 1.        , 0.        , 0.        , 0.        ],
#        [0.11319365, 0.        , 1.        , 0.17782245, 0.06252731],
#        [0.12406331, 0.        , 0.17782245, 1.        , 0.06853163],
#        [0.13308737, 0.        , 0.06252731, 0.06853163, 1.        ]])

# %%
# Name:Khan Alfia Shamusl uin: 231A025
similarity_df = pd.DataFrame(similarity_matrix, index=["D1","D2","D3","D4","D5"],
                             columns=["D1","D2","D3","D4","D5"])
similarity_df.round(3)
# Out:
#        D1   D2     D3     D4     D5
# D1  1.000  0.0  0.113  0.124  0.133
# D2  0.000  1.0  0.000  0.000  0.000
# D3  0.113  0.0  1.000  0.178  0.063
# D4  0.124  0.0  0.178  1.000  0.069
# D5  0.133  0.0  0.063  0.069  1.000

# %%
# Name:Khan Alfia Shamusl uin: 231A025
highest_similarity = -1
most_similar_pair = None
for i in range(len(similarity_matrix)):
    for j in range(i + 1, len(similarity_matrix)):
        if similarity_matrix[i][j] > highest_similarity:
            highest_similarity = similarity_matrix[i][j]
            most_similar_pair = (i,j)
print("Most Similar Documents:", most_similar_pair)
print("Similarity Score:", highest_similarity)
print(f"similarity: {highest_similarity:.3f}")
# Out:
#   File "/tmp/ipykernel_1210/3384729773.py", line 11
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
# Name:Khan Alfia Shamusl uin: 231A025

# %%
# Name:Khan Alfia Shamusl uin: 231A025

# %%
# Name:Khan Alfia Shamusl uin: 231A025
